# %%
import settings.config as cfg

preprocessed_dataset_folder = cfg.preprocessed_dataset_folder
group_sizes_to_create = cfg.group_sizes_to_create
group_similarity_to_create = cfg.group_similarity_to_create
group_number = cfg.group_number

print(group_number)
# Out:
# 20

# %%
import pandas as pd

ratings_df = pd.read_csv(preprocessed_dataset_folder+"/ratings.csv") 
display(ratings_df.head(10))
# Out:
#    user  item  rating
# 0     1  1193       5
# 1     1   661       3
# 2     1   914       3
# 3     1  3408       4
# 4     1  2355       5
# 5     1  1197       3
# 6     1  1287       5
# 7     1  2804       5
# 8     1   594       4
# 9     1   919       4

# %% [markdown]
# # Similarity evaluation
#
# Evaluation of the similarity between all the pairs o users in the dataset.

# %%
# computing similarity between each pair of users

import numpy as np

user_matrix = ratings_df.pivot_table(columns='item', index='user', values='rating')

user_id_set = set(ratings_df['user'])
user_id_indexes = user_matrix.index.values
user_matrix = user_matrix.fillna(0)
numpy_array = user_matrix.to_numpy()
sim_matrix = np.corrcoef(numpy_array)

# display(sim_matrix)
# display(list(user_id_indexes))
# display(user_id_set)

# %% [markdown]
# ## Visualization of the similarity distribution

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(sim_matrix.flatten())
plt.yscale("log")
plt.xlabel("Pearson's Correlation Coeficient")
# Out:
# Text(0.5, 0, "Pearson's Correlation Coeficient")

# %%
from synthetic_groups_generation.groups_generators import GroupsGenerator

group_list = list()
for group_type in group_similarity_to_create:
    print(group_type)
    grpGenerator = GroupsGenerator.getGroupsGenerator(group_type)
    current_list = grpGenerator.generateGroups(user_id_indexes, user_id_set, sim_matrix, group_sizes_to_create, group_number)
    
    display(pd.DataFrame.from_records(current_list))
    
    group_list = group_list + current_list
# Out:
# SIMILAR
# 20
# 40
# 60
#     group_size group_similarity  \
# 0            4          similar
# 1            4          similar
# 2            4          similar
# 3            4          similar
# 4            4          similar
# 5            4          similar
# 6            4          similar
# 7            4          similar
# 8            4          similar
# 9            4          similar
# 10           4          similar
# 11           4          similar
# 12           4          similar
# 13           4          similar
# 14           4          similar
# 15           4          similar
# 16           4          similar
# 17           4          similar
# 18           4          similar
# 19           4          similar
# 20           6          similar
# 21           6          similar
# 22           6          similar
# 23           6          similar
# 24           6          similar
# 25           6          similar
# 26           6          similar
# 27           6          similar
# 28           6          similar
# 29           6          similar
# 30           6          similar
# 31           6          similar
# 32           6          similar
# 33           6          similar
# 34           6          similar
# 35           6          similar
# 36           6          similar
# 37           6          similar
# 38           6          similar
# 39           6          similar
# 40           8          similar
# 41           8          similar
# 42           8          similar
# 43           8          similar
# 44           8          similar
# 45           8          similar
# 46           8          similar
# 47           8          similar
# 48           8          similar
# 49           8          similar
# 50           8          similar
# 51           8          similar
# 52           8          similar
# 53           8          similar
# 54           8          similar
# 55           8          similar
# 56           8          similar
# 57           8          similar
# 58           8          similar
# 59           8          similar
#
#                                        group_members  avg_similarity
# 0                           [5216, 1719, 5507, 3991]        0.476936
# 1                           [2380, 4089, 4033, 2645]        0.430140
# 2                           [3705, 5667, 1899, 3380]        0.452490
# 3                             [751, 1531, 972, 1462]        0.427203
# 4                            [1226, 821, 1615, 1480]        0.507324
# 5                              [602, 17, 4406, 1215]        0.470543
# 6                           [2163, 3599, 5177, 1414]        0.437966
# 7                           [1826, 5187, 4245, 1598]        0.459905
# 8                            [4455, 1608, 370, 2780]        0.448284
# 9                            [4055, 3450, 2051, 368]        0.425307
# 10                          [4506, 1693, 4948, 2544]        0.451443
# 11                          [3771, 2857, 4049, 2186]        0.441313
# 12                           [2466, 602, 1598, 5389]        0.493715
# 13                          [2163, 5177, 1414, 3599]        0.437966
# 14                          [5167, 5778, 5592, 3874]        0.442898
# 15                          [5018, 4090, 6002, 4253]        0.420342
# 16                          [3352, 5929, 4185, 3806]        0.457276
# 17                               [4, 4143, 5842, 87]        0.458728
# 18                           [1632, 6040, 1899, 588]        0.454160
# 19                           [210, 2886, 4377, 3955]        0.499850
# 20                [629, 2999, 634, 3486, 5420, 2003]        0.525605
# 21                [1473, 29, 5679, 4018, 1031, 4130]        0.497524
# 22               [5968, 105, 1575, 3534, 1578, 3666]        0.462837
# 23                [1624, 130, 1726, 2186, 1497, 174]        0.471766
# 24               [4167, 651, 4979, 5627, 4238, 1333]        0.434683
# 25                [3648, 5682, 3669, 272, 757, 3471]        0.435986
# 26                  [354, 70, 2005, 1608, 506, 1769]        0.511557
# 27               [172, 5069, 5999, 2373, 4974, 6034]        0.532178
# 28                [802, 3265, 5720, 533, 4238, 3929]        0.432899
# 29              [5617, 1349, 5873, 6008, 2539, 5842]        0.491305
# 30              [2651, 3809, 1349, 3666, 4320, 3906]        0.477083
# 31                [3050, 1522, 742, 2013, 5338, 602]        0.494532
# 32                 [778, 1578, 1961, 29, 5994, 5731]        0.430761
# 33              [1902, 4965, 1803, 4377, 3209, 3599]        0.463637
# 34              [5947, 4245, 4160, 2013, 1522, 5997]        0.559100
# 35               [477, 4148, 5531, 1490, 2254, 1320]        0.470870
# 36               [3828, 4668, 422, 5984, 4618, 5778]        0.515437
# 37              [5581, 2254, 1961, 5994, 2146, 1349]        0.458120
# 38                 [2194, 42, 2403, 4291, 949, 1031]        0.477153
# 39               [1931, 1357, 3352, 4031, 278, 4185]        0.514561
# 40  [1249, 5474, 2126, 5778, 4239, 3660, 1665, 4245]        0.509624
# 41   [820, 3820, 1723, 3010, 3012, 2284, 1856, 4245]        0.479644
# 42  [4291, 2445, 1030, 1358, 5679, 3400, 1031, 3242]        0.484257
# 43    [1769, 2196, 675, 2005, 2199, 2655, 1438, 506]        0.490758
# 44   [3352, 5597, 1357, 6005, 2352, 278, 3998, 3528]        0.514510
# 45      [3909, 370, 135, 5933, 2780, 3851, 1160, 39]        0.487190
# 46  [5289, 4948, 1884, 5517, 2030, 3402, 4888, 2753]        0.441533
# 47   [3828, 4065, 5882, 422, 1771, 3354, 1522, 5088]        0.487032
# 48   [820, 1856, 3169, 2167, 2126, 2921, 4160, 3731]        0.528372
# 49   [700, 3623, 2373, 6034, 5069, 1026, 4974, 5999]        0.542134
# 50    [5994, 1000, 1188, 2254, 3631, 1578, 87, 2539]        0.473971
# 51   [5187, 2868, 5338, 2354, 3169, 1206, 602, 1522]        0.503845
# 52     [42, 1159, 4333, 2126, 4245, 2921, 1135, 602]        0.516873
# 53     [2189, 2958, 2891, 70, 135, 4067, 1769, 1160]        0.496365
# 54   [3443, 2284, 4668, 586, 4065, 3354, 1245, 4176]        0.477380
# 55   [472, 3092, 5778, 5474, 4065, 3354, 1522, 1245]        0.500666
# 56   [1598, 4668, 1215, 3456, 2740, 820, 1665, 1985]        0.477561
# 57  [1884, 4506, 1274, 2030, 1899, 2478, 2544, 4948]        0.462557
# 58  [3209, 4965, 4284, 3599, 4004, 2186, 4699, 4377]        0.474749
# 59   [1031, 3169, 3012, 6011, 5617, 4291, 4287, 949]        0.462778
# DIVERGENT
# 20
# 40
# 60
#     group_size group_similarity  \
# 0            4        divergent
# 1            4        divergent
# 2            4        divergent
# 3            4        divergent
# 4            4        divergent
# 5            4        divergent
# 6            4        divergent
# 7            4        divergent
# 8            4        divergent
# 9            4        divergent
# 10           4        divergent
# 11           4        divergent
# 12           4        divergent
# 13           4        divergent
# 14           4        divergent
# 15           4        divergent
# 16           4        divergent
# 17           4        divergent
# 18           4        divergent
# 19           4        divergent
# 20           6        divergent
# 21           6        divergent
# 22           6        divergent
# 23           6        divergent
# 24           6        divergent
# 25           6        divergent
# 26           6        divergent
# 27           6        divergent
# 28           6        divergent
# 29           6        divergent
# 30           6        divergent
# 31           6        divergent
# 32           6        divergent
# 33           6        divergent
# 34           6        divergent
# 35           6        divergent
# 36           6        divergent
# 37           6        divergent
# 38           6        divergent
# 39           6        divergent
# 40           8        divergent
# 41           8        divergent
# 42           8        divergent
# 43           8        divergent
# 44           8        divergent
# 45           8        divergent
# 46           8        divergent
# 47           8        divergent
# 48           8        divergent
# 49           8        divergent
# 50           8        divergent
# 51           8        divergent
# 52           8        divergent
# 53           8        divergent
# 54           8        divergent
# 55           8        divergent
# 56           8        divergent
# 57           8        divergent
# 58           8        divergent
# 59           8        divergent
#
#                                        group_members  avg_similarity
# 0                           [5955, 5945, 2033, 4255]       -0.019934
# 1                           [4384, 4241, 3214, 5012]       -0.015762
# 2                           [5177, 5313, 3314, 1171]       -0.022427
# 3                             [1038, 4334, 2999, 61]       -0.033695
# 4                             [575, 5551, 879, 5146]       -0.010266
# 5                           [1787, 3814, 4270, 3897]       -0.011935
# 6                           [1781, 5711, 3478, 1735]       -0.014539
# 7                             [1012, 73, 2441, 4672]       -0.009650
# 8                           [3837, 1037, 4377, 2204]       -0.023188
# 9                            [1601, 5447, 629, 4211]       -0.028263
# 10                          [3771, 3390, 4001, 4651]       -0.038904
# 11                          [1206, 5384, 5967, 3328]       -0.016995
# 12                          [4222, 4010, 3254, 1037]       -0.015933
# 13                           [1322, 779, 5101, 2204]       -0.015943
# 14                          [2489, 4109, 5006, 5146]       -0.019328
# 15                           [3342, 415, 4061, 2738]       -0.012172
# 16                            [788, 1382, 2735, 986]       -0.017179
# 17                           [3191, 5048, 1754, 304]       -0.015805
# 18                          [2103, 5004, 5348, 1478]       -0.012095
# 19                          [1820, 3542, 1111, 5783]       -0.013244
# 20               [817, 3485, 1174, 4365, 2111, 3570]       -0.011657
# 21               [2637, 2156, 1864, 250, 4255, 2123]       -0.014501
# 22               [680, 2292, 2710, 5669, 2352, 4192]       -0.013706
# 23               [2581, 3902, 4697, 4751, 4211, 278]       -0.022992
# 24              [2116, 5768, 4575, 4108, 5174, 4061]       -0.016488
# 25                 [5704, 4334, 951, 12, 1713, 5467]       -0.012877
# 26                 [2120, 3776, 750, 1562, 432, 112]       -0.017880
# 27              [1765, 4288, 5897, 5089, 5551, 1615]       -0.013822
# 28                 [4401, 1197, 43, 5783, 709, 4838]       -0.013343
# 29              [2507, 1300, 2204, 4569, 4211, 2123]       -0.020421
# 30                [3874, 2514, 2584, 5727, 741, 823]       -0.012055
# 31              [1542, 2171, 1424, 2361, 3043, 2204]       -0.013549
# 32                [5964, 1191, 4100, 61, 2123, 3642]       -0.015232
# 33              [1291, 3046, 1501, 2204, 1539, 5577]       -0.014466
# 34                [1785, 931, 2623, 356, 4211, 3538]       -0.011925
# 35               [110, 1505, 4278, 2155, 3979, 4997]       -0.018622
# 36               [4439, 2121, 5977, 3375, 4427, 947]       -0.011961
# 37                   [2986, 4584, 75, 61, 835, 5101]       -0.020688
# 38               [299, 4613, 3111, 2475, 1092, 2483]       -0.012178
# 39              [5257, 1042, 5400, 2677, 3352, 1065]       -0.018577
# 40   [4775, 708, 5999, 2999, 3585, 4185, 1102, 4997]       -0.016812
# 41    [4406, 826, 2003, 1770, 432, 2834, 4196, 1562]       -0.016647
# 42  [4770, 1346, 3984, 4211, 4572, 2834, 4295, 1562]       -0.014665
# 43   [4475, 164, 3168, 4365, 4270, 2155, 1023, 5897]       -0.013438
# 44     [2502, 5223, 5793, 356, 2111, 46, 5238, 4282]       -0.009647
# 45  [4446, 2151, 2697, 1576, 4211, 1573, 2982, 1305]       -0.013313
# 46   [5044, 3968, 1893, 2999, 835, 1382, 4014, 1562]       -0.019072
# 47   [5434, 1277, 210, 5420, 1838, 3570, 2204, 4295]       -0.016052
# 48   [5304, 2999, 4692, 6005, 4207, 805, 4105, 2687]       -0.021320
# 49  [5218, 3696, 1417, 2123, 3972, 1341, 5680, 4804]       -0.017019
# 50  [3983, 1537, 3998, 4211, 2999, 6012, 3043, 1305]       -0.018475
# 51   [145, 4399, 5526, 5772, 1226, 3662, 4244, 2886]       -0.013817
# 52    [5629, 1092, 990, 741, 1963, 4672, 4804, 2204]       -0.015766
# 53  [3034, 2483, 3897, 5951, 2584, 1919, 2413, 1123]       -0.011963
# 54   [4004, 588, 5144, 6005, 4192, 1615, 5420, 4295]       -0.018842
# 55    [4964, 3634, 4572, 46, 1615, 2708, 2204, 4211]       -0.014656
# 56    [1420, 5751, 2361, 2373, 1621, 2204, 3319, 46]       -0.016110
# 57  [5319, 3802, 4196, 3939, 4749, 1615, 2123, 5238]       -0.011282
# 58   [3484, 2733, 4974, 3352, 2834, 1615, 365, 5529]       -0.012214
# 59  [1664, 2690, 5476, 3582, 3642, 1864, 3528, 2483]       -0.012588
# SIMILAR_ONE_DIVERGENT
# 20
# 40
# 60
#     group_size       group_similarity  \
# 0            4  similar_one_divergent
# 1            4  similar_one_divergent
# 2            4  similar_one_divergent
# 3            4  similar_one_divergent
# 4            4  similar_one_divergent
# 5            4  similar_one_divergent
# 6            4  similar_one_divergent
# 7            4  similar_one_divergent
# 8            4  similar_one_divergent
# 9            4  similar_one_divergent
# 10           4  similar_one_divergent
# 11           4  similar_one_divergent
# 12           4  similar_one_divergent
# 13           4  similar_one_divergent
# 14           4  similar_one_divergent
# 15           4  similar_one_divergent
# 16           4  similar_one_divergent
# 17           4  similar_one_divergent
# 18           4  similar_one_divergent
# 19           4  similar_one_divergent
# 20           6  similar_one_divergent
# 21           6  similar_one_divergent
# 22           6  similar_one_divergent
# 23           6  similar_one_divergent
# 24           6  similar_one_divergent
# 25           6  similar_one_divergent
# 26           6  similar_one_divergent
# 27           6  similar_one_divergent
# 28           6  similar_one_divergent
# 29           6  similar_one_divergent
# 30           6  similar_one_divergent
# 31           6  similar_one_divergent
# 32           6  similar_one_divergent
# 33           6  similar_one_divergent
# 34           6  similar_one_divergent
# 35           6  similar_one_divergent
# 36           6  similar_one_divergent
# 37           6  similar_one_divergent
# 38           6  similar_one_divergent
# 39           6  similar_one_divergent
# 40           8  similar_one_divergent
# 41           8  similar_one_divergent
# 42           8  similar_one_divergent
# 43           8  similar_one_divergent
# 44           8  similar_one_divergent
# 45           8  similar_one_divergent
# 46           8  similar_one_divergent
# 47           8  similar_one_divergent
# 48           8  similar_one_divergent
# 49           8  similar_one_divergent
# 50           8  similar_one_divergent
# 51           8  similar_one_divergent
# 52           8  similar_one_divergent
# 53           8  similar_one_divergent
# 54           8  similar_one_divergent
# 55           8  similar_one_divergent
# 56           8  similar_one_divergent
# 57           8  similar_one_divergent
# 58           8  similar_one_divergent
# 59           8  similar_one_divergent
#
#                                        group_members  avg_similarity
# 0                           [5475, 2446, 3280, 3979]        0.201416
# 1                           [4022, 4167, 1058, 2123]        0.191978
# 2                           [3719, 1934, 5883, 3980]        0.214679
# 3                           [1793, 1086, 5689, 1191]        0.193567
# 4                             [2288, 1077, 1019, 46]        0.200628
# 5                           [1584, 4715, 2105, 2483]        0.190722
# 6                            [5495, 2325, 145, 1216]        0.233763
# 7                             [4147, 729, 130, 2024]        0.193293
# 8                           [3724, 5015, 2537, 3245]        0.189840
# 9                              [680, 3851, 70, 3781]        0.252906
# 10                             [5237, 4, 5842, 3186]        0.208682
# 11                          [2599, 2848, 3274, 1102]        0.206815
# 12                           [4317, 5127, 472, 1226]        0.211199
# 13                           [386, 3685, 2023, 5768]        0.191432
# 14                           [4267, 597, 2973, 1634]        0.226955
# 15                           [692, 1264, 3425, 2623]        0.196437
# 16                           [4946, 931, 4888, 1533]        0.194140
# 17                          [3717, 5404, 1712, 2204]        0.186860
# 18                            [676, 4089, 2887, 825]        0.203783
# 19                           [2931, 746, 2840, 2483]        0.205996
# 20              [5968, 5358, 4966, 3535, 5842, 1615]        0.309208
# 21              [3218, 4067, 1608, 4679, 1269, 5152]        0.313522
# 22               [1338, 2146, 3022, 5994, 876, 5362]        0.294986
# 23                 [929, 272, 533, 4386, 3768, 3039]        0.285552
# 24              [2575, 5531, 6024, 3242, 5679, 1562]        0.314565
# 25                [1166, 542, 1462, 1384, 427, 1189]        0.305051
# 26                [327, 307, 5463, 1896, 5517, 1096]        0.297437
# 27               [636, 3678, 4210, 4272, 1135, 1102]        0.340726
# 28               [1337, 3486, 2999, 114, 5420, 4134]        0.325439
# 29              [6018, 4049, 2126, 1723, 4291, 4326]        0.284570
# 30              [3676, 1215, 4245, 1665, 3660, 5459]        0.339681
# 31              [1522, 3317, 4245, 4978, 3169, 2390]        0.327714
# 32                [173, 1019, 2967, 1077, 2544, 714]        0.283623
# 33              [4156, 4287, 4049, 1358, 1726, 5751]        0.303086
# 34               [4227, 651, 5550, 4238, 4386, 2863]        0.282580
# 35              [1751, 2087, 1166, 1915, 1906, 4102]        0.293900
# 36               [3715, 1312, 3274, 563, 3678, 4925]        0.328664
# 37                [218, 1608, 597, 2199, 4067, 3251]        0.326710
# 38                [1512, 458, 2113, 427, 2149, 1012]        0.318410
# 39              [2102, 1628, 1836, 5493, 3425, 4743]        0.289200
# 40  [1472, 4287, 4018, 4261, 1030, 2445, 5531, 1205]        0.351044
# 41   [3414, 2894, 4130, 1030, 1031, 2445, 4747, 594]        0.329721
# 42    [4424, 1578, 3534, 105, 562, 4002, 3809, 3608]        0.334285
# 43   [381, 3828, 3010, 1522, 3092, 3354, 4200, 4813]        0.391551
# 44    [262, 4333, 6030, 3169, 563, 3678, 1159, 5974]        0.350278
# 45   [803, 5994, 5263, 3631, 3671, 2146, 2254, 1205]        0.342587
# 46  [2894, 4747, 1030, 2186, 1031, 2445, 4130, 2003]        0.348379
# 47   [4213, 2651, 2946, 5679, 477, 1490, 4130, 2364]        0.354715
# 48   [3820, 3954, 1856, 5778, 1665, 5617, 336, 2160]        0.356378
# 49  [4087, 1160, 1679, 3851, 3395, 4409, 1769, 2018]        0.365291
# 50    [2958, 1831, 643, 3223, 4067, 3851, 135, 3841]        0.383203
# 51    [5715, 1349, 5473, 5842, 876, 5994, 1304, 614]        0.323926
# 52    [5679, 3353, 4351, 3414, 4018, 3242, 477, 304]        0.343499
# 53  [5127, 3050, 2354, 1665, 1522, 5338, 2284, 5033]        0.366000
# 54   [2575, 1490, 3671, 604, 4130, 1468, 3242, 2123]        0.333242
# 55   [117, 1675, 3715, 2180, 2599, 3274, 3665, 2301]        0.326395
# 56     [1179, 2599, 949, 42, 2789, 3169, 1215, 3895]        0.338244
# 57    [4287, 477, 5531, 3771, 949, 2651, 4985, 1810]        0.341715
# 58   [5014, 2132, 2421, 602, 4245, 3169, 5338, 2123]        0.379892
# 59   [1719, 1876, 5965, 3164, 1438, 492, 2052, 1576]        0.344533
# TWO_DIVERGENT_SUBGROUPS
# 20
# 40
# 60
#     group_size         group_similarity  \
# 0            4  two_divergent_subgroups
# 1            4  two_divergent_subgroups
# 2            4  two_divergent_subgroups
# 3            4  two_divergent_subgroups
# 4            4  two_divergent_subgroups
# 5            4  two_divergent_subgroups
# 6            4  two_divergent_subgroups
# 7            4  two_divergent_subgroups
# 8            4  two_divergent_subgroups
# 9            4  two_divergent_subgroups
# 10           4  two_divergent_subgroups
# 11           4  two_divergent_subgroups
# 12           4  two_divergent_subgroups
# 13           4  two_divergent_subgroups
# 14           4  two_divergent_subgroups
# 15           4  two_divergent_subgroups
# 16           4  two_divergent_subgroups
# 17           4  two_divergent_subgroups
# 18           4  two_divergent_subgroups
# 19           4  two_divergent_subgroups
# 20           6  two_divergent_subgroups
# 21           6  two_divergent_subgroups
# 22           6  two_divergent_subgroups
# 23           6  two_divergent_subgroups
# 24           6  two_divergent_subgroups
# 25           6  two_divergent_subgroups
# 26           6  two_divergent_subgroups
# 27           6  two_divergent_subgroups
# 28           6  two_divergent_subgroups
# 29           6  two_divergent_subgroups
# 30           6  two_divergent_subgroups
# 31           6  two_divergent_subgroups
# 32           6  two_divergent_subgroups
# 33           6  two_divergent_subgroups
# 34           6  two_divergent_subgroups
# 35           6  two_divergent_subgroups
# 36           6  two_divergent_subgroups
# 37           6  two_divergent_subgroups
# 38           6  two_divergent_subgroups
# 39           6  two_divergent_subgroups
# 40           8  two_divergent_subgroups
# 41           8  two_divergent_subgroups
# 42           8  two_divergent_subgroups
# 43           8  two_divergent_subgroups
# 44           8  two_divergent_subgroups
# 45           8  two_divergent_subgroups
# 46           8  two_divergent_subgroups
# 47           8  two_divergent_subgroups
# 48           8  two_divergent_subgroups
# 49           8  two_divergent_subgroups
# 50           8  two_divergent_subgroups
# 51           8  two_divergent_subgroups
# 52           8  two_divergent_subgroups
# 53           8  two_divergent_subgroups
# 54           8  two_divergent_subgroups
# 55           8  two_divergent_subgroups
# 56           8  two_divergent_subgroups
# 57           8  two_divergent_subgroups
# 58           8  two_divergent_subgroups
# 59           8  two_divergent_subgroups
#
#                                        group_members  avg_similarity
# 0                           [1949, 2933, 3662, 2204]        0.157419
# 1                            [2247, 656, 3189, 1958]        0.114506
# 2                               [472, 3354, 45, 594]        0.136577
# 3                            [1958, 3562, 437, 3949]        0.136618
# 4                             [5050, 726, 868, 1357]        0.127719
# 5                            [5227, 2886, 3583, 106]        0.131495
# 6                           [3555, 4683, 5979, 5928]        0.146988
# 7                           [1224, 1899, 5965, 5817]        0.138056
# 8                           [4733, 4364, 1877, 1037]        0.128804
# 9                           [3020, 1387, 2447, 1770]        0.137806
# 10                           [4512, 5908, 2204, 835]        0.177296
# 11                           [897, 5657, 3998, 1357]        0.134489
# 12                            [4901, 1681, 967, 813]        0.123969
# 13                          [4818, 4595, 5714, 5123]        0.129061
# 14                          [4385, 4383, 1377, 3499]        0.130495
# 15                           [3698, 2551, 4649, 688]        0.151427
# 16                           [1773, 574, 5531, 4261]        0.148164
# 17                           [3391, 710, 3039, 2329]        0.127923
# 18                           [736, 2022, 3801, 3844]        0.143789
# 19                           [3315, 4217, 5999, 172]        0.131082
# 20              [3186, 6034, 2373, 1026, 2377, 3534]        0.212807
# 21               [996, 5453, 5776, 5339, 5929, 1357]        0.204092
# 22               [2529, 1422, 264, 3272, 3865, 3838]        0.188758
# 23               [2630, 2314, 2973, 643, 2274, 1042]        0.199347
# 24                 [4102, 278, 2352, 3806, 48, 1120]        0.203483
# 25              [1899, 1693, 2753, 5848, 3209, 4965]        0.182212
# 26              [5558, 1312, 3715, 3274, 2426, 1569]        0.199669
# 27               [302, 1246, 3311, 2054, 5310, 5517]        0.165523
# 28                [301, 3471, 2446, 676, 5069, 3623]        0.198537
# 29                [531, 3562, 1958, 4085, 1863, 670]        0.196782
# 30               [526, 4862, 2254, 4966, 1919, 2155]        0.209245
# 31               [5069, 1295, 304, 3623, 3366, 2539]        0.224766
# 32               [2407, 2030, 3402, 2185, 647, 4390]        0.170118
# 33               [2020, 169, 1579, 2895, 1919, 2155]        0.185520
# 34                 [2472, 409, 5475, 2641, 75, 2003]        0.182769
# 35               [2288, 3054, 3821, 1077, 4284, 210]        0.180454
# 36               [3685, 5475, 1303, 2105, 629, 5420]        0.183001
# 37              [2496, 4506, 4373, 2478, 2085, 5896]        0.163330
# 38              [1113, 4823, 3685, 2023, 3806, 4102]        0.179446
# 39              [3681, 3746, 3669, 4058, 2329, 3039]        0.189049
# 40    [5510, 3809, 5263, 2435, 5994, 5731, 304, 112]        0.245213
# 41   [1348, 2003, 2999, 3486, 5420, 634, 4049, 4160]        0.265803
# 42       [542, 2087, 717, 612, 1633, 427, 580, 4073]        0.257778
# 43   [5848, 2478, 1693, 4948, 1899, 2544, 4377, 210]        0.229745
# 44  [5358, 5842, 3666, 3535, 5968, 2388, 1719, 5507]        0.263808
# 45    [2338, 2354, 1856, 5338, 3169, 42, 5302, 4572]        0.261590
# 46    [1349, 526, 105, 4966, 1093, 1575, 2320, 1107]        0.259151
# 47   [2509, 1575, 4002, 3461, 562, 1578, 1615, 1226]        0.272067
# 48    [87, 3534, 4320, 3535, 5842, 1093, 1453, 4394]        0.258112
# 49      [1738, 3851, 1411, 70, 1608, 39, 4285, 1377]        0.274436
# 50   [316, 1358, 2013, 2126, 3874, 1206, 1100, 2029]        0.262516
# 51  [4334, 5997, 1598, 4972, 2921, 5338, 4619, 1254]        0.268847
# 52    [5712, 5617, 876, 288, 5994, 2254, 5896, 2085]        0.246549
# 53     [5741, 2013, 4978, 602, 4245, 3660, 77, 2317]        0.290910
# 54    [929, 3768, 1790, 5720, 651, 4386, 3779, 5768]        0.234679
# 55  [2435, 2146, 2651, 1093, 1349, 3809, 3979, 2999]        0.244522
# 56    [256, 4130, 2651, 477, 1490, 1497, 1107, 2320]        0.257128
# 57    [172, 5999, 2373, 1026, 3623, 6034, 262, 4272]        0.291099
# 58      [1563, 657, 2298, 1608, 70, 643, 4018, 1667]        0.263222
# 59   [1826, 5014, 3731, 602, 4160, 6026, 1175, 3577]        0.251757

# %%
# group_list = group_list_random + group_list_similar + group_list_divergent + group_list_sim_one_div
#group_list = group_list_sim_one_div

group_dict = dict()
for group_id, group in zip(range(len(group_list)), group_list):
    group_dict[group_id] = group
display(group_dict)
# Out:
# {0: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [5216, 1719, 5507, 3991],
#   'avg_similarity': 0.4769364074638578},
#  1: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [2380, 4089, 4033, 2645],
#   'avg_similarity': 0.4301397516719929},
#  2: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [3705, 5667, 1899, 3380],
#   'avg_similarity': 0.45248960621650397},
#  3: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [751, 1531, 972, 1462],
#   'avg_similarity': 0.42720340373218163},
#  4: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [1226, 821, 1615, 1480],
#   'avg_similarity': 0.5073239729328669},
#  5: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [602, 17, 4406, 1215],
#   'avg_similarity': 0.4705429091540348},
#  6: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [2163, 3599, 5177, 1414],
#   'avg_similarity': 0.4379661947184709},
#  7: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [1826, 5187, 4245, 1598],
#   'avg_similarity': 0.4599050210852474},
#  8: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [4455, 1608, 370, 2780],
#   'avg_similarity': 0.44828397518835733},
#  9: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [4055, 3450, 2051, 368],
#   'avg_similarity': 0.42530650247851165},
#  10: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [4506, 1693, 4948, 2544],
#   'avg_similarity': 0.4514430463583823},
#  11: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [3771, 2857, 4049, 2186],
#   'avg_similarity': 0.44131326638163193},
#  12: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [2466, 602, 1598, 5389],
#   'avg_similarity': 0.4937147511403273},
#  13: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [2163, 5177, 1414, 3599],
#   'avg_similarity': 0.4379661947184709},
#  14: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [5167, 5778, 5592, 3874],
#   'avg_similarity': 0.4428977220410357},
#  15: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [5018, 4090, 6002, 4253],
#   'avg_similarity': 0.4203419638011623},
#  16: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [3352, 5929, 4185, 3806],
#   'avg_similarity': 0.4572763771774732},
#  17: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [4, 4143, 5842, 87],
#   'avg_similarity': 0.4587282520131626},
#  18: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [1632, 6040, 1899, 588],
#   'avg_similarity': 0.4541601297547106},
#  19: {'group_size': 4,
#   'group_similarity': 'similar',
#   'group_members': [210, 2886, 4377, 3955],
#   'avg_similarity': 0.49984965437336415},
#  20: {'group_size': 6,
#   'group_similarity': 'similar',
#   'group_members': [629, 2999, 634, 3486, 5420, 2003],
#   'avg_similarity': 0.525605464563585},
#  21: {'group_size': 6,
#   'group_similarity': 'similar',
#   'group_members': [1473, 29, 5679, 4018, 1031, 4130],
#   'avg_similarity': 0.4975244620021914},
#  22: {'group_size': 6,
#   'group_similarity': 'similar',
#   'group_members': [5968, 105, 1575, 3534, 1578, 3666],
#   'avg_similarity': 0.4628367518935882},
#  23: {'group_size': 6,
#   'group_similarity': 'similar',
#   'group_members': [1624, 130, 1726, 2186, 1497, 174],
#   'avg_similarity': 0.47176599605646496},
#  24: {'group_size': 6,
#   'group_similarity': 'similar',
#   'group_members': [4167, 651, 4979, 5627, 4238, 1333],
#   'avg_similarity': 0.4346834917159506},
#  25: {'group_size': 6,
#   'group_similarity': 'similar',
#   'group_members': [3648, 5682, 3669, 272, 757, 3471],
#   'avg_similarity': 0.4359863724146115},
#  26: {'group_size': 6,
#   'group_similarity': 'similar',
#   'group_members': [354, 70, 2005, 1608, 506, 1769],
#   'avg_similarity': 0.5115572321722842},
#  27: {'group_size': 6,
#   'group_similarity': 'similar',
#   'group_members': [172, 5069, 5999, 2373, 4974, 6034],
#   'avg_similarity': 0.5321781761983605},
#  28: {'group_size': 6,
#   'group_similarity': 'similar',
#   'group_members': [802, 3265, 5720, 533, 4238, 3929],
#   'avg_similarity': 0.43289855827933976},
#  29: {'group_size': 6,
#   'group_similarity': 'similar',
#   'group_members': [5617, 1349, 5873, 6008, 2539, 5842],
#   'avg_similarity': 0.49130494346524745},
#  30: {'group_size': 6,
#   'group_similarity': 'similar',
#   'group_members': [2651, 3809, 1349, 3666, 4320, 3906],
#   'avg_similarity': 0.4770830508632728},
#  31: {'group_size': 6,
#   'group_similarity': 'similar',
#   'group_members': [3050, 1522, 742, 2013, 5338, 602],
#   'avg_similarity': 0.49453210779420353},
#  32: {'group_size': 6,
#   'group_similarity': 'similar',
#   'group_members': [778, 1578, 1961, 29, 5994, 5731],
#   'avg_similarity': 0.43076121026356134},
#  33: {'group_size': 6,
#   'group_similarity': 'similar',
#   'group_members': [1902, 4965, 1803, 4377, 3209, 3599],
#   'avg_similarity': 0.4636370484546725},
#  34: {'group_size': 6,
#   'group_similarity': 'similar',
#   'group_members': [5947, 4245, 4160, 2013, 1522, 5997],
#   'avg_similarity': 0.5590997901004608},
#  35: {'group_size': 6,
#   'group_similarity': 'similar',
#   'group_members': [477, 4148, 5531, 1490, 2254, 1320],
#   'avg_similarity': 0.470870104629925},
#  36: {'group_size': 6,
#   'group_similarity': 'similar',
#   'group_members': [3828, 4668, 422, 5984, 4618, 5778],
#   'avg_similarity': 0.5154371615140992},
#  37: {'group_size': 6,
#   'group_similarity': 'similar',
#   'group_members': [5581, 2254, 1961, 5994, 2146, 1349],
#   'avg_similarity': 0.4581203969199808},
#  38: {'group_size': 6,
#   'group_similarity': 'similar',
#   'group_members': [2194, 42, 2403, 4291, 949, 1031],
#   'avg_similarity': 0.47715259432371987},
#  39: {'group_size': 6,
#   'group_similarity': 'similar',
#   'group_members': [1931, 1357, 3352, 4031, 278, 4185],
#   'avg_similarity': 0.5145609949439027},
#  40: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1249, 5474, 2126, 5778, 4239, 3660, 1665, 4245],
#   'avg_similarity': 0.509624103659944},
#  41: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [820, 3820, 1723, 3010, 3012, 2284, 1856, 4245],
#   'avg_similarity': 0.47964371671282724},
#  42: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [4291, 2445, 1030, 1358, 5679, 3400, 1031, 3242],
#   'avg_similarity': 0.4842573701834057},
#  43: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1769, 2196, 675, 2005, 2199, 2655, 1438, 506],
#   'avg_similarity': 0.49075800984775014},
#  44: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [3352, 5597, 1357, 6005, 2352, 278, 3998, 3528],
#   'avg_similarity': 0.5145101577737886},
#  45: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [3909, 370, 135, 5933, 2780, 3851, 1160, 39],
#   'avg_similarity': 0.4871899933198537},
#  46: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [5289, 4948, 1884, 5517, 2030, 3402, 4888, 2753],
#   'avg_similarity': 0.44153259031348796},
#  47: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [3828, 4065, 5882, 422, 1771, 3354, 1522, 5088],
#   'avg_similarity': 0.48703215312930453},
#  48: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [820, 1856, 3169, 2167, 2126, 2921, 4160, 3731],
#   'avg_similarity': 0.5283718209844187},
#  49: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [700, 3623, 2373, 6034, 5069, 1026, 4974, 5999],
#   'avg_similarity': 0.5421339005438937},
#  50: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [5994, 1000, 1188, 2254, 3631, 1578, 87, 2539],
#   'avg_similarity': 0.4739712655014109},
#  51: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [5187, 2868, 5338, 2354, 3169, 1206, 602, 1522],
#   'avg_similarity': 0.5038451969925354},
#  52: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [42, 1159, 4333, 2126, 4245, 2921, 1135, 602],
#   'avg_similarity': 0.516872956558908},
#  53: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [2189, 2958, 2891, 70, 135, 4067, 1769, 1160],
#   'avg_similarity': 0.496365147934842},
#  54: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [3443, 2284, 4668, 586, 4065, 3354, 1245, 4176],
#   'avg_similarity': 0.4773802843148164},
#  55: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [472, 3092, 5778, 5474, 4065, 3354, 1522, 1245],
#   'avg_similarity': 0.5006659152025418},
#  56: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1598, 4668, 1215, 3456, 2740, 820, 1665, 1985],
#   'avg_similarity': 0.47756145533431316},
#  57: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1884, 4506, 1274, 2030, 1899, 2478, 2544, 4948],
#   'avg_similarity': 0.4625574070754486},
#  58: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [3209, 4965, 4284, 3599, 4004, 2186, 4699, 4377],
#   'avg_similarity': 0.474748663802289},
#  59: {'group_size': 8,
#   'group_similarity': 'similar',
#   'group_members': [1031, 3169, 3012, 6011, 5617, 4291, 4287, 949],
#   'avg_similarity': 0.4627775027136335},
#  60: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [5955, 5945, 2033, 4255],
#   'avg_similarity': -0.01993432391456008},
#  61: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [4384, 4241, 3214, 5012],
#   'avg_similarity': -0.01576210663412825},
#  62: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [5177, 5313, 3314, 1171],
#   'avg_similarity': -0.02242713853222406},
#  63: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1038, 4334, 2999, 61],
#   'avg_similarity': -0.03369460151243951},
#  64: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [575, 5551, 879, 5146],
#   'avg_similarity': -0.010265948800395771},
#  65: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1787, 3814, 4270, 3897],
#   'avg_similarity': -0.011935265577227046},
#  66: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1781, 5711, 3478, 1735],
#   'avg_similarity': -0.01453874661093131},
#  67: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1012, 73, 2441, 4672],
#   'avg_similarity': -0.009649954227542008},
#  68: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [3837, 1037, 4377, 2204],
#   'avg_similarity': -0.023188015255902764},
#  69: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1601, 5447, 629, 4211],
#   'avg_similarity': -0.02826257901150085},
#  70: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [3771, 3390, 4001, 4651],
#   'avg_similarity': -0.03890381107519388},
#  71: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1206, 5384, 5967, 3328],
#   'avg_similarity': -0.016995179614670362},
#  72: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [4222, 4010, 3254, 1037],
#   'avg_similarity': -0.01593290061500648},
#  73: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1322, 779, 5101, 2204],
#   'avg_similarity': -0.01594311625229312},
#  74: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [2489, 4109, 5006, 5146],
#   'avg_similarity': -0.019327577883935573},
#  75: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [3342, 415, 4061, 2738],
#   'avg_similarity': -0.012172288666678119},
#  76: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [788, 1382, 2735, 986],
#   'avg_similarity': -0.01717938909483131},
#  77: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [3191, 5048, 1754, 304],
#   'avg_similarity': -0.015805369996663963},
#  78: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [2103, 5004, 5348, 1478],
#   'avg_similarity': -0.012095454420575788},
#  79: {'group_size': 4,
#   'group_similarity': 'divergent',
#   'group_members': [1820, 3542, 1111, 5783],
#   'avg_similarity': -0.013244457225274174},
#  80: {'group_size': 6,
#   'group_similarity': 'divergent',
#   'group_members': [817, 3485, 1174, 4365, 2111, 3570],
#   'avg_similarity': -0.011657390877668209},
#  81: {'group_size': 6,
#   'group_similarity': 'divergent',
#   'group_members': [2637, 2156, 1864, 250, 4255, 2123],
#   'avg_similarity': -0.014500824531035347},
#  82: {'group_size': 6,
#   'group_similarity': 'divergent',
#   'group_members': [680, 2292, 2710, 5669, 2352, 4192],
#   'avg_similarity': -0.01370560488533185},
#  83: {'group_size': 6,
#   'group_similarity': 'divergent',
#   'group_members': [2581, 3902, 4697, 4751, 4211, 278],
#   'avg_similarity': -0.022991696318897935},
#  84: {'group_size': 6,
#   'group_similarity': 'divergent',
#   'group_members': [2116, 5768, 4575, 4108, 5174, 4061],
#   'avg_similarity': -0.01648757024616525},
#  85: {'group_size': 6,
#   'group_similarity': 'divergent',
#   'group_members': [5704, 4334, 951, 12, 1713, 5467],
#   'avg_similarity': -0.012877180838246466},
#  86: {'group_size': 6,
#   'group_similarity': 'divergent',
#   'group_members': [2120, 3776, 750, 1562, 432, 112],
#   'avg_similarity': -0.017880224640884297},
#  87: {'group_size': 6,
#   'group_similarity': 'divergent',
#   'group_members': [1765, 4288, 5897, 5089, 5551, 1615],
#   'avg_similarity': -0.013821640630559847},
#  88: {'group_size': 6,
#   'group_similarity': 'divergent',
#   'group_members': [4401, 1197, 43, 5783, 709, 4838],
#   'avg_similarity': -0.01334335310392255},
#  89: {'group_size': 6,
#   'group_similarity': 'divergent',
#   'group_members': [2507, 1300, 2204, 4569, 4211, 2123],
#   'avg_similarity': -0.0204211419587218},
#  90: {'group_size': 6,
#   'group_similarity': 'divergent',
#   'group_members': [3874, 2514, 2584, 5727, 741, 823],
#   'avg_similarity': -0.012054885781792249},
#  91: {'group_size': 6,
#   'group_similarity': 'divergent',
#   'group_members': [1542, 2171, 1424, 2361, 3043, 2204],
#   'avg_similarity': -0.013548534648951517},
#  92: {'group_size': 6,
#   'group_similarity': 'divergent',
#   'group_members': [5964, 1191, 4100, 61, 2123, 3642],
#   'avg_similarity': -0.01523194374603477},
#  93: {'group_size': 6,
#   'group_similarity': 'divergent',
#   'group_members': [1291, 3046, 1501, 2204, 1539, 5577],
#   'avg_similarity': -0.014465513744215614},
#  94: {'group_size': 6,
#   'group_similarity': 'divergent',
#   'group_members': [1785, 931, 2623, 356, 4211, 3538],
#   'avg_similarity': -0.011924760235510487},
#  95: {'group_size': 6,
#   'group_similarity': 'divergent',
#   'group_members': [110, 1505, 4278, 2155, 3979, 4997],
#   'avg_similarity': -0.01862176928579125},
#  96: {'group_size': 6,
#   'group_similarity': 'divergent',
#   'group_members': [4439, 2121, 5977, 3375, 4427, 947],
#   'avg_similarity': -0.011961209467454338},
#  97: {'group_size': 6,
#   'group_similarity': 'divergent',
#   'group_members': [2986, 4584, 75, 61, 835, 5101],
#   'avg_similarity': -0.020688135972614145},
#  98: {'group_size': 6,
#   'group_similarity': 'divergent',
#   'group_members': [299, 4613, 3111, 2475, 1092, 2483],
#   'avg_similarity': -0.012178347375633645},
#  99: {'group_size': 6,
#   'group_similarity': 'divergent',
#   'group_members': [5257, 1042, 5400, 2677, 3352, 1065],
#   'avg_similarity': -0.018576873075630676},
#  100: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [4775, 708, 5999, 2999, 3585, 4185, 1102, 4997],
#   'avg_similarity': -0.016811685102406652},
#  101: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [4406, 826, 2003, 1770, 432, 2834, 4196, 1562],
#   'avg_similarity': -0.0166465897139017},
#  102: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [4770, 1346, 3984, 4211, 4572, 2834, 4295, 1562],
#   'avg_similarity': -0.014665050589560052},
#  103: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [4475, 164, 3168, 4365, 4270, 2155, 1023, 5897],
#   'avg_similarity': -0.01343829083487683},
#  104: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [2502, 5223, 5793, 356, 2111, 46, 5238, 4282],
#   'avg_similarity': -0.009646815503045534},
#  105: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [4446, 2151, 2697, 1576, 4211, 1573, 2982, 1305],
#   'avg_similarity': -0.013312973723577667},
#  106: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [5044, 3968, 1893, 2999, 835, 1382, 4014, 1562],
#   'avg_similarity': -0.01907169178752579},
#  107: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [5434, 1277, 210, 5420, 1838, 3570, 2204, 4295],
#   'avg_similarity': -0.016052086853944762},
#  108: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [5304, 2999, 4692, 6005, 4207, 805, 4105, 2687],
#   'avg_similarity': -0.021319944340666478},
#  109: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [5218, 3696, 1417, 2123, 3972, 1341, 5680, 4804],
#   'avg_similarity': -0.01701907489330795},
#  110: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [3983, 1537, 3998, 4211, 2999, 6012, 3043, 1305],
#   'avg_similarity': -0.018475315865506083},
#  111: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [145, 4399, 5526, 5772, 1226, 3662, 4244, 2886],
#   'avg_similarity': -0.013816806961448809},
#  112: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [5629, 1092, 990, 741, 1963, 4672, 4804, 2204],
#   'avg_similarity': -0.015765623513392925},
#  113: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [3034, 2483, 3897, 5951, 2584, 1919, 2413, 1123],
#   'avg_similarity': -0.011963211383843403},
#  114: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [4004, 588, 5144, 6005, 4192, 1615, 5420, 4295],
#   'avg_similarity': -0.018841700859490385},
#  115: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [4964, 3634, 4572, 46, 1615, 2708, 2204, 4211],
#   'avg_similarity': -0.014656358411105295},
#  116: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [1420, 5751, 2361, 2373, 1621, 2204, 3319, 46],
#   'avg_similarity': -0.01611029498658881},
#  117: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [5319, 3802, 4196, 3939, 4749, 1615, 2123, 5238],
#   'avg_similarity': -0.011282058967875588},
#  118: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [3484, 2733, 4974, 3352, 2834, 1615, 365, 5529],
#   'avg_similarity': -0.012213613634376183},
#  119: {'group_size': 8,
#   'group_similarity': 'divergent',
#   'group_members': [1664, 2690, 5476, 3582, 3642, 1864, 3528, 2483],
#   'avg_similarity': -0.012588430042696039},
#  120: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5475, 2446, 3280, 3979],
#   'avg_similarity': 0.20141572223702608},
#  121: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4022, 4167, 1058, 2123],
#   'avg_similarity': 0.19197847053327546},
#  122: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3719, 1934, 5883, 3980],
#   'avg_similarity': 0.21467876130215702},
#  123: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1793, 1086, 5689, 1191],
#   'avg_similarity': 0.19356693625623358},
#  124: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2288, 1077, 1019, 46],
#   'avg_similarity': 0.20062754244623549},
#  125: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1584, 4715, 2105, 2483],
#   'avg_similarity': 0.19072164714316286},
#  126: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5495, 2325, 145, 1216],
#   'avg_similarity': 0.23376264725969378},
#  127: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4147, 729, 130, 2024],
#   'avg_similarity': 0.19329274565338997},
#  128: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3724, 5015, 2537, 3245],
#   'avg_similarity': 0.18983999132979676},
#  129: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [680, 3851, 70, 3781],
#   'avg_similarity': 0.25290612658045253},
#  130: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5237, 4, 5842, 3186],
#   'avg_similarity': 0.20868224407925395},
#  131: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2599, 2848, 3274, 1102],
#   'avg_similarity': 0.20681461150731037},
#  132: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4317, 5127, 472, 1226],
#   'avg_similarity': 0.21119852529510033},
#  133: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [386, 3685, 2023, 5768],
#   'avg_similarity': 0.19143238969068266},
#  134: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4267, 597, 2973, 1634],
#   'avg_similarity': 0.2269552003421749},
#  135: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [692, 1264, 3425, 2623],
#   'avg_similarity': 0.19643687331720006},
#  136: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4946, 931, 4888, 1533],
#   'avg_similarity': 0.19413968598283726},
#  137: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3717, 5404, 1712, 2204],
#   'avg_similarity': 0.1868600041198836},
#  138: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [676, 4089, 2887, 825],
#   'avg_similarity': 0.20378340919244028},
#  139: {'group_size': 4,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2931, 746, 2840, 2483],
#   'avg_similarity': 0.20599602147328924},
#  140: {'group_size': 6,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5968, 5358, 4966, 3535, 5842, 1615],
#   'avg_similarity': 0.30920826774003163},
#  141: {'group_size': 6,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3218, 4067, 1608, 4679, 1269, 5152],
#   'avg_similarity': 0.31352175218507905},
#  142: {'group_size': 6,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1338, 2146, 3022, 5994, 876, 5362],
#   'avg_similarity': 0.29498575183341263},
#  143: {'group_size': 6,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [929, 272, 533, 4386, 3768, 3039],
#   'avg_similarity': 0.28555184401984046},
#  144: {'group_size': 6,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2575, 5531, 6024, 3242, 5679, 1562],
#   'avg_similarity': 0.31456507190947536},
#  145: {'group_size': 6,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1166, 542, 1462, 1384, 427, 1189],
#   'avg_similarity': 0.3050513759418706},
#  146: {'group_size': 6,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [327, 307, 5463, 1896, 5517, 1096],
#   'avg_similarity': 0.2974374290793086},
#  147: {'group_size': 6,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [636, 3678, 4210, 4272, 1135, 1102],
#   'avg_similarity': 0.3407255963169503},
#  148: {'group_size': 6,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1337, 3486, 2999, 114, 5420, 4134],
#   'avg_similarity': 0.3254385216926111},
#  149: {'group_size': 6,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [6018, 4049, 2126, 1723, 4291, 4326],
#   'avg_similarity': 0.28456955778094106},
#  150: {'group_size': 6,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3676, 1215, 4245, 1665, 3660, 5459],
#   'avg_similarity': 0.3396808084667865},
#  151: {'group_size': 6,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1522, 3317, 4245, 4978, 3169, 2390],
#   'avg_similarity': 0.3277142003658875},
#  152: {'group_size': 6,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [173, 1019, 2967, 1077, 2544, 714],
#   'avg_similarity': 0.28362280571890486},
#  153: {'group_size': 6,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4156, 4287, 4049, 1358, 1726, 5751],
#   'avg_similarity': 0.3030856885960617},
#  154: {'group_size': 6,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4227, 651, 5550, 4238, 4386, 2863],
#   'avg_similarity': 0.2825801318609289},
#  155: {'group_size': 6,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1751, 2087, 1166, 1915, 1906, 4102],
#   'avg_similarity': 0.29389952072664965},
#  156: {'group_size': 6,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3715, 1312, 3274, 563, 3678, 4925],
#   'avg_similarity': 0.3286636985433073},
#  157: {'group_size': 6,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [218, 1608, 597, 2199, 4067, 3251],
#   'avg_similarity': 0.3267095807822637},
#  158: {'group_size': 6,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1512, 458, 2113, 427, 2149, 1012],
#   'avg_similarity': 0.318409715921882},
#  159: {'group_size': 6,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2102, 1628, 1836, 5493, 3425, 4743],
#   'avg_similarity': 0.28919985895689637},
#  160: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1472, 4287, 4018, 4261, 1030, 2445, 5531, 1205],
#   'avg_similarity': 0.35104424742791135},
#  161: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3414, 2894, 4130, 1030, 1031, 2445, 4747, 594],
#   'avg_similarity': 0.3297207050483789},
#  162: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4424, 1578, 3534, 105, 562, 4002, 3809, 3608],
#   'avg_similarity': 0.3342849048240982},
#  163: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [381, 3828, 3010, 1522, 3092, 3354, 4200, 4813],
#   'avg_similarity': 0.3915512605658654},
#  164: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [262, 4333, 6030, 3169, 563, 3678, 1159, 5974],
#   'avg_similarity': 0.35027787649329983},
#  165: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [803, 5994, 5263, 3631, 3671, 2146, 2254, 1205],
#   'avg_similarity': 0.34258692652058703},
#  166: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2894, 4747, 1030, 2186, 1031, 2445, 4130, 2003],
#   'avg_similarity': 0.3483793023377085},
#  167: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4213, 2651, 2946, 5679, 477, 1490, 4130, 2364],
#   'avg_similarity': 0.35471508898300524},
#  168: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [3820, 3954, 1856, 5778, 1665, 5617, 336, 2160],
#   'avg_similarity': 0.3563783030660062},
#  169: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4087, 1160, 1679, 3851, 3395, 4409, 1769, 2018],
#   'avg_similarity': 0.36529098701202073},
#  170: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2958, 1831, 643, 3223, 4067, 3851, 135, 3841],
#   'avg_similarity': 0.3832025030201813},
#  171: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5715, 1349, 5473, 5842, 876, 5994, 1304, 614],
#   'avg_similarity': 0.3239264607541866},
#  172: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5679, 3353, 4351, 3414, 4018, 3242, 477, 304],
#   'avg_similarity': 0.34349923552930595},
#  173: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5127, 3050, 2354, 1665, 1522, 5338, 2284, 5033],
#   'avg_similarity': 0.36599994532352376},
#  174: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [2575, 1490, 3671, 604, 4130, 1468, 3242, 2123],
#   'avg_similarity': 0.3332422599150874},
#  175: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [117, 1675, 3715, 2180, 2599, 3274, 3665, 2301],
#   'avg_similarity': 0.32639450557550675},
#  176: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1179, 2599, 949, 42, 2789, 3169, 1215, 3895],
#   'avg_similarity': 0.3382442504427311},
#  177: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [4287, 477, 5531, 3771, 949, 2651, 4985, 1810],
#   'avg_similarity': 0.3417151530923311},
#  178: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [5014, 2132, 2421, 602, 4245, 3169, 5338, 2123],
#   'avg_similarity': 0.3798916724836142},
#  179: {'group_size': 8,
#   'group_similarity': 'similar_one_divergent',
#   'group_members': [1719, 1876, 5965, 3164, 1438, 492, 2052, 1576],
#   'avg_similarity': 0.3445334905089944},
#  180: {'group_size': 4,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [1949, 2933, 3662, 2204],
#   'avg_similarity': 0.15741875266764466},
#  181: {'group_size': 4,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [2247, 656, 3189, 1958],
#   'avg_similarity': 0.11450633689719725},
#  182: {'group_size': 4,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [472, 3354, 45, 594],
#   'avg_similarity': 0.1365767945934569},
#  183: {'group_size': 4,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [1958, 3562, 437, 3949],
#   'avg_similarity': 0.1366178780772961},
#  184: {'group_size': 4,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [5050, 726, 868, 1357],
#   'avg_similarity': 0.12771911357877744},
#  185: {'group_size': 4,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [5227, 2886, 3583, 106],
#   'avg_similarity': 0.13149475111804493},
#  186: {'group_size': 4,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [3555, 4683, 5979, 5928],
#   'avg_similarity': 0.14698799179146013},
#  187: {'group_size': 4,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [1224, 1899, 5965, 5817],
#   'avg_similarity': 0.13805606356076094},
#  188: {'group_size': 4,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [4733, 4364, 1877, 1037],
#   'avg_similarity': 0.128803675406011},
#  189: {'group_size': 4,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [3020, 1387, 2447, 1770],
#   'avg_similarity': 0.13780583597371346},
#  190: {'group_size': 4,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [4512, 5908, 2204, 835],
#   'avg_similarity': 0.17729616156482172},
#  191: {'group_size': 4,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [897, 5657, 3998, 1357],
#   'avg_similarity': 0.1344885910640717},
#  192: {'group_size': 4,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [4901, 1681, 967, 813],
#   'avg_similarity': 0.12396936275984323},
#  193: {'group_size': 4,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [4818, 4595, 5714, 5123],
#   'avg_similarity': 0.12906054981140025},
#  194: {'group_size': 4,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [4385, 4383, 1377, 3499],
#   'avg_similarity': 0.13049489689324492},
#  195: {'group_size': 4,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [3698, 2551, 4649, 688],
#   'avg_similarity': 0.1514269652162921},
#  196: {'group_size': 4,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [1773, 574, 5531, 4261],
#   'avg_similarity': 0.14816360542025878},
#  197: {'group_size': 4,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [3391, 710, 3039, 2329],
#   'avg_similarity': 0.1279227315387311},
#  198: {'group_size': 4,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [736, 2022, 3801, 3844],
#   'avg_similarity': 0.14378929919560332},
#  199: {'group_size': 4,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [3315, 4217, 5999, 172],
#   'avg_similarity': 0.13108204278200086},
#  200: {'group_size': 6,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [3186, 6034, 2373, 1026, 2377, 3534],
#   'avg_similarity': 0.2128067409212539},
#  201: {'group_size': 6,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [996, 5453, 5776, 5339, 5929, 1357],
#   'avg_similarity': 0.20409220915390863},
#  202: {'group_size': 6,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [2529, 1422, 264, 3272, 3865, 3838],
#   'avg_similarity': 0.1887575486258558},
#  203: {'group_size': 6,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [2630, 2314, 2973, 643, 2274, 1042],
#   'avg_similarity': 0.19934655811659643},
#  204: {'group_size': 6,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [4102, 278, 2352, 3806, 48, 1120],
#   'avg_similarity': 0.2034831414454718},
#  205: {'group_size': 6,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [1899, 1693, 2753, 5848, 3209, 4965],
#   'avg_similarity': 0.18221154401242173},
#  206: {'group_size': 6,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [5558, 1312, 3715, 3274, 2426, 1569],
#   'avg_similarity': 0.19966916284185637},
#  207: {'group_size': 6,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [302, 1246, 3311, 2054, 5310, 5517],
#   'avg_similarity': 0.16552254818646617},
#  208: {'group_size': 6,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [301, 3471, 2446, 676, 5069, 3623],
#   'avg_similarity': 0.19853664477398267},
#  209: {'group_size': 6,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [531, 3562, 1958, 4085, 1863, 670],
#   'avg_similarity': 0.1967815403815522},
#  210: {'group_size': 6,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [526, 4862, 2254, 4966, 1919, 2155],
#   'avg_similarity': 0.2092451293827323},
#  211: {'group_size': 6,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [5069, 1295, 304, 3623, 3366, 2539],
#   'avg_similarity': 0.22476568975398864},
#  212: {'group_size': 6,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [2407, 2030, 3402, 2185, 647, 4390],
#   'avg_similarity': 0.17011783622290094},
#  213: {'group_size': 6,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [2020, 169, 1579, 2895, 1919, 2155],
#   'avg_similarity': 0.18552020265716393},
#  214: {'group_size': 6,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [2472, 409, 5475, 2641, 75, 2003],
#   'avg_similarity': 0.18276949995206102},
#  215: {'group_size': 6,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [2288, 3054, 3821, 1077, 4284, 210],
#   'avg_similarity': 0.1804538395043228},
#  216: {'group_size': 6,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [3685, 5475, 1303, 2105, 629, 5420],
#   'avg_similarity': 0.18300088407632586},
#  217: {'group_size': 6,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [2496, 4506, 4373, 2478, 2085, 5896],
#   'avg_similarity': 0.16333004899370035},
#  218: {'group_size': 6,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [1113, 4823, 3685, 2023, 3806, 4102],
#   'avg_similarity': 0.17944608669092277},
#  219: {'group_size': 6,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [3681, 3746, 3669, 4058, 2329, 3039],
#   'avg_similarity': 0.18904900372831993},
#  220: {'group_size': 8,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [5510, 3809, 5263, 2435, 5994, 5731, 304, 112],
#   'avg_similarity': 0.24521330250396775},
#  221: {'group_size': 8,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [1348, 2003, 2999, 3486, 5420, 634, 4049, 4160],
#   'avg_similarity': 0.26580280584109073},
#  222: {'group_size': 8,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [542, 2087, 717, 612, 1633, 427, 580, 4073],
#   'avg_similarity': 0.25777847228862244},
#  223: {'group_size': 8,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [5848, 2478, 1693, 4948, 1899, 2544, 4377, 210],
#   'avg_similarity': 0.22974456160445816},
#  224: {'group_size': 8,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [5358, 5842, 3666, 3535, 5968, 2388, 1719, 5507],
#   'avg_similarity': 0.26380766872721384},
#  225: {'group_size': 8,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [2338, 2354, 1856, 5338, 3169, 42, 5302, 4572],
#   'avg_similarity': 0.2615898547937216},
#  226: {'group_size': 8,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [1349, 526, 105, 4966, 1093, 1575, 2320, 1107],
#   'avg_similarity': 0.25915145865776373},
#  227: {'group_size': 8,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [2509, 1575, 4002, 3461, 562, 1578, 1615, 1226],
#   'avg_similarity': 0.2720672465421388},
#  228: {'group_size': 8,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [87, 3534, 4320, 3535, 5842, 1093, 1453, 4394],
#   'avg_similarity': 0.2581121031029166},
#  229: {'group_size': 8,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [1738, 3851, 1411, 70, 1608, 39, 4285, 1377],
#   'avg_similarity': 0.27443588976321615},
#  230: {'group_size': 8,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [316, 1358, 2013, 2126, 3874, 1206, 1100, 2029],
#   'avg_similarity': 0.2625157923024993},
#  231: {'group_size': 8,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [4334, 5997, 1598, 4972, 2921, 5338, 4619, 1254],
#   'avg_similarity': 0.2688470215311424},
#  232: {'group_size': 8,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [5712, 5617, 876, 288, 5994, 2254, 5896, 2085],
#   'avg_similarity': 0.2465494461390594},
#  233: {'group_size': 8,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [5741, 2013, 4978, 602, 4245, 3660, 77, 2317],
#   'avg_similarity': 0.2909099816822159},
#  234: {'group_size': 8,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [929, 3768, 1790, 5720, 651, 4386, 3779, 5768],
#   'avg_similarity': 0.23467931613600077},
#  235: {'group_size': 8,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [2435, 2146, 2651, 1093, 1349, 3809, 3979, 2999],
#   'avg_similarity': 0.2445216412092246},
#  236: {'group_size': 8,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [256, 4130, 2651, 477, 1490, 1497, 1107, 2320],
#   'avg_similarity': 0.25712810721375},
#  237: {'group_size': 8,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [172, 5999, 2373, 1026, 3623, 6034, 262, 4272],
#   'avg_similarity': 0.2910985397439677},
#  238: {'group_size': 8,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [1563, 657, 2298, 1608, 70, 643, 4018, 1667],
#   'avg_similarity': 0.2632222960527975},
#  239: {'group_size': 8,
#   'group_similarity': 'two_divergent_subgroups',
#   'group_members': [1826, 5014, 3731, 602, 4160, 6026, 1175, 3577],
#   'avg_similarity': 0.251757008727859}}

# %%
# simple similarity viewer per group
np.set_printoptions(precision=4, suppress=True)
idx = 140
member_index = [user_id_indexes.tolist().index(member) for member in group_dict[idx]["group_members"]]
s = sim_matrix[member_index]
s[:,member_index]
# Out:
# array([[ 1.    ,  0.5009,  0.4643,  0.4083,  0.4935, -0.0105],
#        [ 0.5009,  1.    ,  0.4574,  0.4489,  0.4246, -0.0091],
#        [ 0.4643,  0.4574,  1.    ,  0.4164,  0.5596, -0.0126],
#        [ 0.4083,  0.4489,  0.4164,  1.    ,  0.5196, -0.0098],
#        [ 0.4935,  0.4246,  0.5596,  0.5196,  1.    , -0.0133],
#        [-0.0105, -0.0091, -0.0126, -0.0098, -0.0133,  1.    ]])

# %%
import pickle
pickle.dump(group_dict, open(preprocessed_dataset_folder+"/group_composition.pkl", "wb"))

# %%
group_similarity = "similar_one_divergent"
group_size = 8
histogram_list = []
for gid in group_dict.keys():
    g = group_dict[gid]
    if g["group_similarity"] == group_similarity and g["group_size"] == group_size:
        member_index = [user_id_indexes.tolist().index(member) for member in g["group_members"]]
        s = sim_matrix[member_index]
        histogram_list.extend(s[:,member_index].flatten().tolist())

        
plt.hist(histogram_list)
#plt.yscale("log")
plt.xlabel("PCC for "+group_similarity+" groups, size:"+str(group_size)+" threshold:"+str(cfg.similar_threshold))    
plt.savefig("pcc_"+group_similarity+"_"+str(group_size)+"_"+str(int(cfg.similar_threshold*10))+".png", dpi=300)

# %%
group_similarity = "divergent"
group_size = 8
histogram_list = []
for gid in group_dict.keys():
    g = group_dict[gid]
    if g["group_similarity"] == group_similarity and g["group_size"] == group_size:
        member_index = [user_id_indexes.tolist().index(member) for member in g["group_members"]]
        s = sim_matrix[member_index]
        histogram_list.extend(s[:,member_index].flatten().tolist())

        
plt.hist(histogram_list)
#plt.yscale("log")
plt.xlabel("PCC for "+group_similarity+" groups, size:"+str(group_size)+" threshold:"+str(cfg.dissimilar_threshold))    
plt.savefig("pcc_"+group_similarity+"_"+str(group_size)+"_"+str(int(cfg.dissimilar_threshold*10))+".png", dpi=300)

# %%
groups_list = list()
for group in group_dict:
    groups_list.append(
        {
            'group_id': group,
            'group_size': group_dict[group]['group_size'],
            'group_similarity': group_dict[group]['group_similarity'],
            'group_members': group_dict[group]['group_members'],
            'avg_similarity': group_dict[group]['avg_similarity']
        }
    )

groups_df = pd.DataFrame.from_records(groups_list)
display(groups_df.head(10))
# Out:
#    group_id  group_size group_similarity             group_members  \
# 0         0           4          similar  [5216, 1719, 5507, 3991]
# 1         1           4          similar  [2380, 4089, 4033, 2645]
# 2         2           4          similar  [3705, 5667, 1899, 3380]
# 3         3           4          similar    [751, 1531, 972, 1462]
# 4         4           4          similar   [1226, 821, 1615, 1480]
# 5         5           4          similar     [602, 17, 4406, 1215]
# 6         6           4          similar  [2163, 3599, 5177, 1414]
# 7         7           4          similar  [1826, 5187, 4245, 1598]
# 8         8           4          similar   [4455, 1608, 370, 2780]
# 9         9           4          similar   [4055, 3450, 2051, 368]
#
#    avg_similarity
# 0        0.476936
# 1        0.430140
# 2        0.452490
# 3        0.427203
# 4        0.507324
# 5        0.470543
# 6        0.437966
# 7        0.459905
# 8        0.448284
# 9        0.425307

# %% [markdown]
# ### Comparing groups internal average similarity between the different types and sizes

# %%
import seaborn as sns


plt.rcParams["figure.figsize"] = (20,10)
sns.boxplot(x = groups_df['group_size'],
            y = groups_df['avg_similarity'],
            hue = groups_df['group_similarity'])
import matplotlib.pyplot as plt

# %%
groups_df.to_csv(preprocessed_dataset_folder+"/group_composition.csv")
